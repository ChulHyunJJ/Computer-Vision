# %% [markdown]
# ## 이미지 노이즈 제거

# %% [markdown]
# ### 데이터 로드

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# ### 임의의 노이즈 추가

# %% [markdown]
# ### 노이즈가 추가된 이미지 확인

# %% [markdown]
# ### 모델 정의

# %% [markdown]
# ### 모델 생성 및 컴파일

# %% [markdown]
# ### 모델 학습

# %% [markdown]
# ### 인코더 요약

# %% [markdown]
# ### 디코더 요약

# %% [markdown]
# ### 노이즈가 있는 이미지와 없는 이미지 시각화
