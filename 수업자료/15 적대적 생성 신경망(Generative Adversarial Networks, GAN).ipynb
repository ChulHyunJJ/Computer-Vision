# %% [markdown]
# - 내용 및 코드 참조
#
#   - 케라스 창시자로부터 배우는 딥러닝
#
#   - 미술관에 GAN 딥러닝 실전 프로젝트

# %% [markdown]
# # 적대적 생성 신경망(Generative Adversarial Networks, GAN)
#
# - 2014년, Ian Goodfellow 소개
#
# - VAE와는 다른 방법으로 이미지 잠재 공간을 학습
#
# - 직관적으로 이해하는 방법
#
#   - 가짜 피카소 그림을 그리는 위조범과 이를 판별하는 판매상의 관계
#
#   - 위조품과 진짜 그림을 섞어서 판매상에게 보여주며
#     그림이 진짜인지 가짜인지 판매상은 판별하고 이를 위조범에게 피드백
#
#   - 처음에는 형편없는 그림을 그리다가 점점 피카소의 스타일을 모방하게 되고
#     판매상은 위조품을 구분하는데 점점 더 전문가가 되어감
#
# - GAN의 네트워크
#
#   - 생성자 네트워크(generator network)
#
#     - 랜덤 벡터(잠재 공간의 무작위한 포인트)를 입력으로 받아 이를 합성된 이미지로 디코딩
#
#   - 판별자 네트워크(discriminator netowrk)
#
#     - 이미지(실제 또는 가짜 이미지)를 입력으로 받아 훈련 세트에서 온 이미지인지 생성자가 만든 이미지인지 판별
#
# - GAN은 최적화의 최솟값이 고정되어 있지 않음
#
#   - 보통의 경사하강법은 **고정된 손실공간**에서 언덕을 내려오는 훈련 방법이지만
#     GAN은 매 단계가 조금씩 전체 공간을 바꾸기 때문에 최적화 과정이 최솟값을 찾는 것이 어려움
#
#   - 두 힘간의 평형점을 찾는 시스템
#
#   - 따라서, 학습과정이 매우 어려움
#     즉, 적절한 파라미터를 찾고 조정해야함
#
#   <img src="https://paperswithcode.com/media/methods/gan.jpeg">
#
#   <sub>[이미지 출처] https://paperswithcode.com/method/gan</sub>

# %% [markdown]
# ## GAN의 구현 (DCGAN)
#
# - CIFAR10 데이터셋 사용
#
# - generator 네트워크는 (latent_dim,) 크기의 벡터를 (32, 32, 3) 크기의 이미지로 매핑
#
# - discriminator 네트워크는 (32, 32, 3) 크기의 이미지가 진짜일 확률을 추정하여 이진값으로 매핑
#
# - 생성자와 판별자를 연결하는 gan 네트워크를 만듬
#
#   - gan(x) = discriminator(generator(x))
#
# - 진짜/가짜 레이블과 함께 진짜 이미지와 가짜 이미지 샘플을 사용하여 판별자를 훈련 (일반적인 이미지 분류 모델 훈련과 동일)
#
# - 생성자를 훈련하려면 gan 모델의 손실에 대한 생성자 가중치의 그래디언트를 사용
#
#   - 매 단계마다 생성자에 의해 디코딩된 이미지를 판별자가 "진짜"로 분류하도록 만다는 방향으로 생성자의 가중치를 이동
#
#   - 판별자를 속이도록 생성자를 훈련한다는 말

# %% [markdown]
# ## 학습 방법
#
# - 마지막 활성화 함수로 sigmoid 대신 tanh함수 사용
#
# - 균등분포가 아니고 정규 분포(가우시안 분포)를 사용하여 잠재 공간에서 포인트를 샘플링
#
# - 무작위성을 주입
#
#   - 판별자에 드롭아웃을 사용
#
#   - 판별자를 위해 레이블에 랜덤 노이즈를 추가
#
# - 희소한 그래디언트는 GAN 훈련에 방해가 될 수 있음
#
#   - 최대 풀링 대신 스트라이드 합성곱을 사용하여 다운샘플링
#
#   - ReLU 대신 LeakyReLU 사용
#
# - 생성자에서 픽셀 공간을 균일하게 다루지 못하여 생성된 이미지에서 체스판 모양이 종종 나타남.
#   이를 위해 생성자와 판별자에서 스트라이드 Conv2DTranpose나 Conv2D를 사용할 때 스트라이드 크기로 나누어 질 수 있는 커널 크기 사용
#
#   - 커널 크기가 스트라이드의 배수가 아니면 픽셀이 공평하게 합성곱 되지 않음
#     커널 크기를 스트라이드로 나누었을 때 나머지 크기에 해당하는 픽셀이 더 많이 업샘플링에 참여하게 됨

# %% [markdown]
# ### GAN 생성자 네트워크

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Reshape, Conv2D, Conv2DTranspose, Flatten, Dropout
from tensorflow.keras.models import Model
import numpy as np

# %%
latent_dim = 32
height = 32
width = 32
channels = 3

# %%
generator_input = Input(shape=(latent_dim, ))

# %%
x = Dense(128 * 16 * 16)(generator_input)
x = LeakyReLU()(x)
x = Reshape((16, 16, 128))(x)

x = Conv2D(256, 5, padding='same')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = LeakyReLU()(x)

x = Conv2D(256, 5, padding='same')(x)
x = LeakyReLU()(x)
x = Conv2D(256, 5, padding='same')(x)
x = LeakyReLU()(x)

x = Conv2D(channels, 7, activation='tanh', padding='same')(x)

# %%
generator = Model(generator_input, x)
generator.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32768)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### GAN 판별자 네트워크

# %%
discriminator_input = Input(shape=(height, width, channels))

# %%
x = Conv2D(128, 3)(discriminator_input)
x = LeakyReLU()(x)
x = Conv2D(128, 4, strides=2)(x)
x = LeakyReLU()(x)
x = Conv2D(128, 4, strides=2)(x)
x = LeakyReLU()(x)
x = Conv2D(128, 4, strides=2)(x)
x = LeakyReLU()(x)
x = Flatten()(x)
x = Dropout(0.4)(x)
x = Dense(1, activation='sigmoid')(x)

# %%
discriminator = Model(discriminator_input, x)
discriminator.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
discriminator_optimizer = RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')

# %% [markdown]
# ### 적대적 네트워크
# - 생성자와 판별자를 연결
#
# - 훈련할 때 생성자가 판별자를 속이는 능력이 커지도록 학습
#
# - 잠재 공간의 포인트를 진짜 또는 가짜의 분류 결정으로 변환
#
# - 훈련에 사용되는 target label은 항상 "진짜 이미지"
#
# - 훈련하는 동안 판별자를 동결(학습되지 않도록)하는 것이 매우 중요!
#
#   - 판별자의 가중치가 훈련하는 동안 업데이트되면 판별자는 항상 진짜를 예측하도록 훈련됨

# %%
discriminator.trainable = False

gan_input = Input(shape=(latent_dim, ))
gan_output = discriminator(generator(gan_input))
gan = Model(gan_input, gan_output)

gan_optimizer = RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %% [markdown]
# ### GAN 훈련 구현
#
# - DCGAN 구현
#
# - 매 반복마다 아래의 과정 수행
#
#   1. 잠재 공간에서 무작위로 포인트를 뽑음(랜덤 노이즈)
#
#   2. 랜덤 노이즈를 사용하여 generator에서 이미지를 생성
#
#   3. 생성된 이미지와 진짜 이미지를 섞음
#
#   4. 진짜와 가짜가 섞인 이미지와 이에 대응하는 타깃을 사용하여 discriminator를 훈련
#     타킷은 진짜 또는 가짜
#
#   5. 잠재 공간에서 무작위로 새로운 포인트를 뽑음
#
#   6. 랜덤 벡터를 사용하여 gan을 훈련.
#     모든 타깃은 진짜로 설정.
#     - 판별자가 생성된 이미지를 모두 "진짜 이미지"라고 예측하도록 생성자의 가중치를 업데이트.
#       (판별자는 동결되기 때문에 생성자만 업데이트)

# %%
import os
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing import image

# %% [markdown]
# #### CIFAR10 데이터 로드

# %%
(x_train, y_train), (_, _) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step

# %% [markdown]
# #### 개구리 이미지를 선택

# %%
x_train = x_train[y_train.flatten() == 6]

# %% [markdown]
# #### 데이터 정규화

# %%
x_train = x_train.reshape((x_train.shape[0], ) + (height, width, channels)).astype('float32') / 255.

# %%
iterations = 10000
batch_size = 20

save_dir = '/content/gan_images/'
if not os.path.exists(save_dir):
  os.mkdir(save_dir)

# %% [markdown]
# #### 학습

# %%
start = 0
for step in range(iterations):
  random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
  generated_images = generator.predict(random_latent_vectors)

  stop = start + batch_size
  real_images = x_train[start:stop]
  combined_images = np.concatenate([generated_images, real_images])

  labels = np.concatenate([np.ones((batch_size, 1)), 
                           np.zeros((batch_size, 1))])
  labels += 0.05 * np.random.random(labels.shape)

  d_loss = discriminator.train_on_batch(combined_images, labels)

  random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
  misleading_targets = np.zeros((batch_size, 1))

  a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)

  start += batch_size
  if start > len(x_train) - batch_size:
    start = 0

  if step % 100 == 0:
    gan.save_weights('gan.h5')

    print('\nstep: {}'.format(step))
    print(' distriminator loss: {}'.format(d_loss))
    print(' adversarial loss: {}'.format(a_loss))

    img = image.array_to_img(generated_images[0] * 255., scale=False)
    img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))


    img = image.array_to_img(real_images[0] * 255., scale=False)
    img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# step: 0
#  distriminator loss: 3.329767942428589
#  adversarial loss: 1.4120374203230313e-08
#
# step: 100
#  distriminator loss: 0.5738574266433716
#  adversarial loss: 1.7486385107040405
#
# step: 200
#  distriminator loss: 0.7604314684867859
#  adversarial loss: 0.7906014323234558
#
# step: 300
#  distriminator loss: 0.6959947347640991
#  adversarial loss: 0.7428824305534363
#
# step: 400
#  distriminator loss: 0.7358959913253784
#  adversarial loss: 0.8135126829147339
#
# step: 500
#  distriminator loss: 0.6444106101989746
#  adversarial loss: 2.939875602722168
#
# step: 600
#  distriminator loss: 0.7021505236625671
#  adversarial loss: 0.7563403844833374
#
# step: 700
#  distriminator loss: 0.6928483843803406
#  adversarial loss: 0.7666689157485962
#
# step: 800
#  distriminator loss: 0.7012231945991516
#  adversarial loss: 0.7635749578475952
#
# step: 900
#  distriminator loss: 0.6990806460380554
#  adversarial loss: 0.7568176984786987
#
# step: 1000
#  distriminator loss: 0.7035824656486511
#  adversarial loss: 0.7367218136787415
#
# step: 1100
#  distriminator loss: 0.6909974813461304
#  adversarial loss: 0.7574902176856995
#
# step: 1200
#  distriminator loss: 0.708509624004364
#  adversarial loss: 0.7788739204406738
#
# step: 1300
#  distriminator loss: 0.6937277317047119
#  adversarial loss: 0.7666266560554504
#
# step: 1400
#  distriminator loss: 0.6832114458084106
#  adversarial loss: 0.7412645816802979
#
# step: 1500
#  distriminator loss: 0.7021390199661255
#  adversarial loss: 0.764833927154541
#
# step: 1600
#  distriminator loss: 0.6959254145622253
#  adversarial loss: 0.7459862232208252
#
# step: 1700
#  distriminator loss: 0.6909043192863464
#  adversarial loss: 0.7617117762565613
#
# step: 1800
#  distriminator loss: 0.6858466863632202
#  adversarial loss: 0.7240592241287231
#
# step: 1900
#  distriminator loss: 0.694619357585907
#  adversarial loss: 0.7374762296676636
#
# step: 2000
#  distriminator loss: 0.7093037962913513
#  adversarial loss: 0.736047625541687
#
# step: 2100
#  distriminator loss: 0.6971656680107117
#  adversarial loss: 0.7500810027122498
#
# step: 2200
#  distriminator loss: 0.690283477306366
#  adversarial loss: 0.7228347659111023
#
# step: 2300
#  distriminator loss: 0.6878222227096558
#  adversarial loss: 0.7547273635864258
#
# step: 2400
#  distriminator loss: 0.6948617100715637
#  adversarial loss: 0.761349081993103
#
# step: 2500
#  distriminator loss: 0.7042021751403809
#  adversarial loss: 0.754921555519104
#
# step: 2600
#  distriminator loss: 0.6979456543922424
#  adversarial loss: 0.7408222556114197
#
# step: 2700
#  distriminator loss: 0.6849643588066101
#  adversarial loss: 0.7390289902687073
#
# step: 2800
#  distriminator loss: 0.6907921433448792
#  adversarial loss: 0.7389276623725891
#
# step: 2900
#  distriminator loss: 0.6923521757125854
#  adversarial loss: 0.7585890293121338
#
# step: 3000
#  distriminator loss: 0.7062458992004395
#  adversarial loss: 0.7718024253845215
#
# step: 3100
#  distriminator loss: 0.7088351249694824
#  adversarial loss: 0.798571765422821
#
# step: 3200
#  distriminator loss: 0.6670724153518677
#  adversarial loss: 1.2207790613174438
#
# step: 3300
#  distriminator loss: 0.6911630630493164
#  adversarial loss: 0.7560774087905884
#
# step: 3400
#  distriminator loss: 0.7035723328590393
#  adversarial loss: 0.7443529963493347
#
# step: 3500
#  distriminator loss: 0.695848822593689
#  adversarial loss: 0.7756919264793396
#
# step: 3600
#  distriminator loss: 0.7358255386352539
#  adversarial loss: 0.7812773585319519
#
# step: 3700
#  distriminator loss: 0.6845357418060303
#  adversarial loss: 0.8520167469978333
#
# step: 3800
#  distriminator loss: 0.6792093515396118
#  adversarial loss: 0.6662827730178833
#
# step: 3900
#  distriminator loss: 0.6850835084915161
#  adversarial loss: 0.7897194623947144
#
# step: 4000
#  distriminator loss: 0.6918995976448059
#  adversarial loss: 0.7254506349563599
#
# step: 4100
#  distriminator loss: 0.6877083778381348
#  adversarial loss: 0.7371708154678345
#
# step: 4200
#  distriminator loss: 0.6928218603134155
#  adversarial loss: 0.7576334476470947
#
# step: 4300
#  distriminator loss: 0.6860363483428955
#  adversarial loss: 1.0136728286743164
#
# step: 4400
#  distriminator loss: 0.6960961222648621
#  adversarial loss: 0.7375916242599487
#
# step: 4500
#  distriminator loss: 0.6971873641014099
#  adversarial loss: 0.7174506187438965
#
# step: 4600
#  distriminator loss: 0.6950808763504028
#  adversarial loss: 0.7377225756645203
#
# step: 4700
#  distriminator loss: 0.6881152391433716
#  adversarial loss: 0.782717227935791
#
# step: 4800
#  distriminator loss: 0.6875457167625427
#  adversarial loss: 0.7478911876678467
#
# step: 4900
#  distriminator loss: 0.7338640093803406
#  adversarial loss: 0.6386364102363586
#
# step: 5000
#  distriminator loss: 0.6871998310089111
#  adversarial loss: 0.7268743515014648
#
# step: 5100
#  distriminator loss: 0.6965142488479614
#  adversarial loss: 0.7598384022712708
#
# step: 5200
#  distriminator loss: 0.7064157724380493
#  adversarial loss: 0.6949244141578674
#
# step: 5300
#  distriminator loss: 0.7129033207893372
#  adversarial loss: 0.7831794619560242
#
# step: 5400
#  distriminator loss: 0.7009335160255432
#  adversarial loss: 0.5963786244392395
#
# step: 5500
#  distriminator loss: 0.7007835507392883
#  adversarial loss: 0.740491509437561
#
# step: 5600
#  distriminator loss: 0.6870275735855103
#  adversarial loss: 0.725377082824707
#
# step: 5700
#  distriminator loss: 0.7032793760299683
#  adversarial loss: 0.7719820141792297
#
# step: 5800
#  distriminator loss: 0.6785691976547241
#  adversarial loss: 0.7649450302124023
#
# step: 5900
#  distriminator loss: 0.71825110912323
#  adversarial loss: 1.141296148300171
#
# step: 6000
#  distriminator loss: 0.716078519821167
#  adversarial loss: 0.6767750978469849
#
# step: 6100
#  distriminator loss: 0.6898938417434692
#  adversarial loss: 0.6865995526313782
#
# step: 6200
#  distriminator loss: 0.6949085593223572
#  adversarial loss: 0.7940815687179565
#
# step: 6300
#  distriminator loss: 0.6722097396850586
#  adversarial loss: 0.7889273762702942
#
# step: 6400
#  distriminator loss: 0.6650990843772888
#  adversarial loss: 0.7109411358833313
#
# step: 6500
#  distriminator loss: 0.666643500328064
#  adversarial loss: 0.6521456241607666
#
# step: 6600
#  distriminator loss: 0.6920072436332703
#  adversarial loss: 0.745521068572998
#
# step: 6700
#  distriminator loss: 0.7471587061882019
#  adversarial loss: 0.7205459475517273
#
# step: 6800
#  distriminator loss: 0.7144384980201721
#  adversarial loss: 0.7881947159767151
#
# step: 6900
#  distriminator loss: 0.6930266618728638
#  adversarial loss: 0.8609711527824402
#
# step: 7000
#  distriminator loss: 0.9381920695304871
#  adversarial loss: 1.073242425918579
#
# step: 7100
#  distriminator loss: 0.6715695261955261
#  adversarial loss: 0.7880942821502686
#
# step: 7200
#  distriminator loss: 0.6875026822090149
#  adversarial loss: 0.7952581644058228
#
# step: 7300
#  distriminator loss: 0.7109242677688599
#  adversarial loss: 0.9021368026733398
#
# step: 7400
#  distriminator loss: 0.721753716468811
#  adversarial loss: 0.7855449318885803
#
# step: 7500
#  distriminator loss: 0.6724007725715637
#  adversarial loss: 0.8075895309448242
#
# step: 7600
#  distriminator loss: 0.7768315076828003
#  adversarial loss: 4.619411945343018
#
# step: 7700
#  distriminator loss: 0.6765654683113098
#  adversarial loss: 0.8543580770492554
#
# step: 7800
#  distriminator loss: 0.6824592351913452
#  adversarial loss: 0.8271958231925964
#
# step: 7900
#  distriminator loss: 0.6702202558517456
#  adversarial loss: 0.5761752128601074
#
# step: 8000
#  distriminator loss: 0.6320120096206665
#  adversarial loss: 0.9027141332626343
#
# step: 8100
#  distriminator loss: 0.6473053693771362
#  adversarial loss: 0.838441014289856
#
# step: 8200
#  distriminator loss: 0.6778956651687622
#  adversarial loss: 0.7238627076148987
#
# step: 8300
#  distriminator loss: 0.6682842969894409
#  adversarial loss: 0.6527718305587769
#
# step: 8400
#  distriminator loss: 0.6909334063529968
#  adversarial loss: 0.7554855346679688
#
# step: 8500
#  distriminator loss: 0.6664740443229675
#  adversarial loss: 0.8221597671508789
#
# step: 8600
#  distriminator loss: 0.705145001411438
#  adversarial loss: 1.0139007568359375
#
# step: 8700
#  distriminator loss: 0.6859234571456909
#  adversarial loss: 0.7036648988723755
#
# step: 8800
#  distriminator loss: 0.6830519437789917
#  adversarial loss: 0.8140531778335571
#
# step: 8900
#  distriminator loss: 0.6984174847602844
#  adversarial loss: 0.7413567304611206
#
# step: 9000
#  distriminator loss: 0.6702040433883667
#  adversarial loss: 0.9522169232368469
#
# step: 9100
#  distriminator loss: 0.6664748191833496
#  adversarial loss: 0.7643744945526123
#
# step: 9200
#  distriminator loss: 0.6943362355232239
#  adversarial loss: 1.0271141529083252
#
# step: 9300
#  distriminator loss: 0.6838487386703491
#  adversarial loss: 0.8057882189750671
#
# step: 9400
#  distriminator loss: 0.6933301687240601
#  adversarial loss: 0.791891872882843
#
# step: 9500
#  distriminator loss: 0.7000673413276672
#  adversarial loss: 0.8611288070678711
#
# step: 9600
#  distriminator loss: 0.7133342027664185
#  adversarial loss: 0.7861742973327637
#
# step: 9700
#  distriminator loss: 0.7137776613235474
#  adversarial loss: 0.6475384831428528
#
# step: 9800
#  distriminator loss: 0.7178067564964294
#  adversarial loss: 0.8465768694877625
#
# step: 9900
#  distriminator loss: 0.6634191274642944
#  adversarial loss: 0.6513316035270691

# %% [markdown]
# #### 이미지 생성을 통한 시각화

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %% [markdown]
# - 잠재 공간에서 랜덤한 포인트를 샘플링

# %%
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# %% [markdown]
# - 가짜 이미지로 디코딩

# %%
generated_images = generator.predict(random_latent_vectors)

# %%
print(generated_images.shape)
# Out:
# (10, 32, 32, 3)

# %%
plt.figure(figsize=(20, 8))
for i in range(generated_images.shape[0]):
  plt.subplot(2, 5, i+1)
  img = image.array_to_img(generated_images[i] * 255., scale=False)
  plt.imshow(img)
  plt.xticks([])
  plt.yticks([])

plt.show()
